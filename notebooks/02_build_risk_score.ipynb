# %%
import pandas as pd
from pathlib import Path

current_dir = Path.cwd()

if current_dir.name == "notebooks":
    project_root = current_dir.parent
else:
    project_root = current_dir

feature_path = project_root / "outputs" / "df_feature_for_model.csv"

df_feature = pd.read_csv(feature_path, dtype={"stock_code": str})

print("读取完成")
print("数据形状：", df_feature.shape)
df_feature.head()
